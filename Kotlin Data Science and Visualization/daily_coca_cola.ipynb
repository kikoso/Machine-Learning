// %%
%useLatestDescriptors
%use dataframe
%use kandy

// %%
val dfRaw = DataFrame.readCsv("data/daily_KO.csv")
dfRaw.head()
// Out:
//             <iframe onload="o_resize_iframe_out_5()" style="width:100%;" class="result_container" id="iframe_out_5" frameBorder="0" srcdoc="        &lt;html theme='dark'&gt;
//         &lt;head&gt;
//             &lt;style type=&quot;text&sol;css&quot;&gt;
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
//     white-space: nowrap;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody &gt; tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody &gt; tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody &gt; tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover &gt; td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// &sol;* formatting *&sol;
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
// :root {
//     --scroll-bg: #f5f5f5;
//     --scroll-fg: #b3b3b3;
// }
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;]{
//     --scroll-bg: #3c3c3c;
//     --scroll-fg: #97e1fb;
// }
// body {
//     scrollbar-color: var(--scroll-fg) var(--scroll-bg);
// }
// body::-webkit-scrollbar {
//     width: 10px; &sol;* Mostly for vertical scrollbars *&sol;
//     height: 10px; &sol;* Mostly for horizontal scrollbars *&sol;
// }
// body::-webkit-scrollbar-thumb {
//     background-color: var(--scroll-fg);
// }
// body::-webkit-scrollbar-track {
//     background-color: var(--scroll-bg);
// }
//             &lt;&sol;style&gt;
//         &lt;&sol;head&gt;
//         &lt;body&gt;
//             &lt;table class=&quot;dataframe&quot; id=&quot;df_671088648&quot;&gt;&lt;&sol;table&gt;
//
// &lt;p class=&quot;dataframe_description&quot;&gt;DataFrame: rowsCount = 6, columnsCount = 14&lt;&sol;p&gt;
//
//         &lt;&sol;body&gt;
//         &lt;script&gt;
//             (function () {
//     window.DataFrame = window.DataFrame || new (function () {
//         this.addTable = function (df) {
//             let cols = df.cols;
//             for (let i = 0; i &lt; cols.length; i++) {
//                 for (let c of cols[i].children) {
//                     cols[c].parent = i;
//                 }
//             }
//             df.nrow = 0
//             for (let i = 0; i &lt; df.cols.length; i++) {
//                 if (df.cols[i].values.length &gt; df.nrow) df.nrow = df.cols[i].values.length
//             }
//             if (df.id === df.rootId) {
//                 df.expandedFrames = new Set()
//                 df.childFrames = {}
//                 const table = this.getTableElement(df.id)
//                 table.df = df
//                 for (let i = 0; i &lt; df.cols.length; i++) {
//                     let col = df.cols[i]
//                     if (col.parent === undefined &amp;&amp; col.children.length &gt; 0) col.expanded = true
//                 }
//             } else {
//                 const rootDf = this.getTableData(df.rootId)
//                 rootDf.childFrames[df.id] = df
//             }
//         }
//
//         this.computeRenderData = function (df) {
//             let result = []
//             let pos = 0
//             for (let col = 0; col &lt; df.cols.length; col++) {
//                 if (df.cols[col].parent === undefined)
//                     pos += this.computeRenderDataRec(df.cols, col, pos, 0, result, false, false)
//             }
//             for (let i = 0; i &lt; result.length; i++) {
//                 let row = result[i]
//                 for (let j = 0; j &lt; row.length; j++) {
//                     let cell = row[j]
//                     if (j === 0)
//                         cell.leftBd = false
//                     if (j &lt; row.length - 1) {
//                         let nextData = row[j + 1]
//                         if (nextData.leftBd) cell.rightBd = true
//                         else if (cell.rightBd) nextData.leftBd = true
//                     } else cell.rightBd = false
//                 }
//             }
//             return result
//         }
//
//         this.computeRenderDataRec = function (cols, colId, pos, depth, result, leftBorder, rightBorder) {
//             if (result.length === depth) {
//                 const array = [];
//                 if (pos &gt; 0) {
//                     let j = 0
//                     for (let i = 0; j &lt; pos; i++) {
//                         let c = result[depth - 1][i]
//                         j += c.span
//                         let copy = Object.assign({empty: true}, c)
//                         array.push(copy)
//                     }
//                 }
//                 result.push(array)
//             }
//             const col = cols[colId];
//             let size = 0;
//             if (col.expanded) {
//                 let childPos = pos
//                 for (let i = 0; i &lt; col.children.length; i++) {
//                     let child = col.children[i]
//                     let childLeft = i === 0 &amp;&amp; (col.children.length &gt; 1 || leftBorder)
//                     let childRight = i === col.children.length - 1 &amp;&amp; (col.children.length &gt; 1 || rightBorder)
//                     let childSize = this.computeRenderDataRec(cols, child, childPos, depth + 1, result, childLeft, childRight)
//                     childPos += childSize
//                     size += childSize
//                 }
//             } else {
//                 for (let i = depth + 1; i &lt; result.length; i++)
//                     result[i].push({id: colId, span: 1, leftBd: leftBorder, rightBd: rightBorder, empty: true})
//                 size = 1
//             }
//             let left = leftBorder
//             let right = rightBorder
//             if (size &

// %%
dfRaw.describe()
// Out:
//             <iframe onload="o_resize_iframe_out_3()" style="width:100%;" class="result_container" id="iframe_out_3" frameBorder="0" srcdoc="        &lt;html theme='dark'&gt;
//         &lt;head&gt;
//             &lt;style type=&quot;text&sol;css&quot;&gt;
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
//     white-space: nowrap;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody &gt; tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody &gt; tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody &gt; tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover &gt; td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// &sol;* formatting *&sol;
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
// :root {
//     --scroll-bg: #f5f5f5;
//     --scroll-fg: #b3b3b3;
// }
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;]{
//     --scroll-bg: #3c3c3c;
//     --scroll-fg: #97e1fb;
// }
// body {
//     scrollbar-color: var(--scroll-fg) var(--scroll-bg);
// }
// body::-webkit-scrollbar {
//     width: 10px; &sol;* Mostly for vertical scrollbars *&sol;
//     height: 10px; &sol;* Mostly for horizontal scrollbars *&sol;
// }
// body::-webkit-scrollbar-thumb {
//     background-color: var(--scroll-fg);
// }
// body::-webkit-scrollbar-track {
//     background-color: var(--scroll-bg);
// }
//             &lt;&sol;style&gt;
//         &lt;&sol;head&gt;
//         &lt;body&gt;
//             &lt;table class=&quot;dataframe&quot; id=&quot;df_788529156&quot;&gt;&lt;&sol;table&gt;
//
// &lt;p class=&quot;dataframe_description&quot;&gt;DataFrame: rowsCount = 6, columnsCount = 14&lt;&sol;p&gt;
//
//         &lt;&sol;body&gt;
//         &lt;script&gt;
//             (function () {
//     window.DataFrame = window.DataFrame || new (function () {
//         this.addTable = function (df) {
//             let cols = df.cols;
//             for (let i = 0; i &lt; cols.length; i++) {
//                 for (let c of cols[i].children) {
//                     cols[c].parent = i;
//                 }
//             }
//             df.nrow = 0
//             for (let i = 0; i &lt; df.cols.length; i++) {
//                 if (df.cols[i].values.length &gt; df.nrow) df.nrow = df.cols[i].values.length
//             }
//             if (df.id === df.rootId) {
//                 df.expandedFrames = new Set()
//                 df.childFrames = {}
//                 const table = this.getTableElement(df.id)
//                 table.df = df
//                 for (let i = 0; i &lt; df.cols.length; i++) {
//                     let col = df.cols[i]
//                     if (col.parent === undefined &amp;&amp; col.children.length &gt; 0) col.expanded = true
//                 }
//             } else {
//                 const rootDf = this.getTableData(df.rootId)
//                 rootDf.childFrames[df.id] = df
//             }
//         }
//
//         this.computeRenderData = function (df) {
//             let result = []
//             let pos = 0
//             for (let col = 0; col &lt; df.cols.length; col++) {
//                 if (df.cols[col].parent === undefined)
//                     pos += this.computeRenderDataRec(df.cols, col, pos, 0, result, false, false)
//             }
//             for (let i = 0; i &lt; result.length; i++) {
//                 let row = result[i]
//                 for (let j = 0; j &lt; row.length; j++) {
//                     let cell = row[j]
//                     if (j === 0)
//                         cell.leftBd = false
//                     if (j &lt; row.length - 1) {
//                         let nextData = row[j + 1]
//                         if (nextData.leftBd) cell.rightBd = true
//                         else if (cell.rightBd) nextData.leftBd = true
//                     } else cell.rightBd = false
//                 }
//             }
//             return result
//         }
//
//         this.computeRenderDataRec = function (cols, colId, pos, depth, result, leftBorder, rightBorder) {
//             if (result.length === depth) {
//                 const array = [];
//                 if (pos &gt; 0) {
//                     let j = 0
//                     for (let i = 0; j &lt; pos; i++) {
//                         let c = result[depth - 1][i]
//                         j += c.span
//                         let copy = Object.assign({empty: true}, c)
//                         array.push(copy)
//                     }
//                 }
//                 result.push(array)
//             }
//             const col = cols[colId];
//             let size = 0;
//             if (col.expanded) {
//                 let childPos = pos
//                 for (let i = 0; i &lt; col.children.length; i++) {
//                     let child = col.children[i]
//                     let childLeft = i === 0 &amp;&amp; (col.children.length &gt; 1 || leftBorder)
//                     let childRight = i === col.children.length - 1 &amp;&amp; (col.children.length &gt; 1 || rightBorder)
//                     let childSize = this.computeRenderDataRec(cols, child, childPos, depth + 1, result, childLeft, childRight)
//                     childPos += childSize
//                     size += childSize
//                 }
//             } else {
//                 for (let i = depth + 1; i &lt; result.length; i++)
//                     result[i].push({id: colId, span: 1, leftBd: leftBorder, rightBd: rightBorder, empty: true})
//                 size = 1
//             }
//             let left = leftBorder
//             let right = rightBorder
//             if (size &

// %%
dfRaw.plot {
    line {
        x(timestamp)
        y(close)
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;mRGKGN&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//        var plotSpec={
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;low&quot;:[64.08,64.43,64.55,64.38,63.92,63.76,62.99,62.59,61.86,61.74,62.55,63.0,63.2,63.36,63.92,63.66,63.7,65.37,65.11,65.01,65.31,65.92,65.56,66.67,66.92,67.3,68.01,69.45,69.45,70.44,69.9,70.57,70.34,70.34,69.57,69.25,69.57,69.18,69.01,70.17,70.52,71.01,71.71,71.86,71.79,71.4,71.45,71.33,71.73,71.64,70.62,71.75,71.8,72.1,71.41,71.23,71.08,71.55,71.85,71.14,71.17,72.56,73.01,72.47,72.05,71.75,71.5,70.84,69.79,69.33,69.57,69.38,68.98,69.18,68.65,68.58,68.46,68.17,68.68,68.73,68.46,68.05,68.1,69.33,67.96,66.74,67.68,66.83,67.05,66.07,65.81,64.96,64.77,65.29,65.19,65.21,64.27,63.41,63.7,63.1,62.83,62.69,62.96,63.76,63.33,63.15,63.28,63.65,63.91,64.05,63.84,63.97,62.77,62.18,62.63,62.62,62.55,62.99,62.88,63.55,63.59,63.91,64.15,63.92,63.94,62.93,62.93,61.97,61.7,61.82,62.0,62.09,63.0,62.91,62.57,63.03,63.32,63.13,63.1,63.58,63.
,64.18,63.12,62.32,62.54,63.08,62.98,62.11,61.3,60.6,59.49,59.7,58.64,60.0,60.73,60.75,61.01,62.87,62.99,62.38,63.33,63.57,63.18,63.42,64.08,64.26,64.07,64.0,62.88,61.65,60.49,60.96,65.42,66.1,65.44,64.81,64.16,64.33,64.5,64.47,64.2,64.69,63.0,63.72,65.28,65.87,64.66,65.0,65.52,67.0,66.08,65.98,65.44,64.5,64.77,64.96,64.44,64.38,63.905,63.48,63.13,62.77,62.4,62.6,62.33,62.22,62.01,62.21,61.53,61.12,60.64,60.75,60.93,6 ...

// %%
dfRaw.head(20).plot {
    candlestick(timestamp, open, high, low, close)
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;W06cHK&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//        var plotSpec={
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;name&quot;:&quot;timestamp&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;name&quot;:&quot;&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;datetime&quot;:true,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;fill&quot;,
// &quot;values&quot;:[&quot;#3ba272&quot;,&quot;#ee6666&quot;],
// &quot;limits&quot;:[true,false],
// &quot;guide&quot;:&quot;none&quot;
// },{
// &quot;aesthetic&quot;:&quot;color&quot;,
// &quot;values&quot;:[&quot;#3ba272&quot;,&quot;#ee6666&quot;],
// &quot;limits&quot;:[true,false],
// &quot;guide&quot;:&quot;none&quot;
// },{
// &quot;aesthetic&quot;:&quot;linetype&quot;,
// &quot;values&quot;:[1.0,1.0],
// &quot;limits&quot;:[true,false],
// &quot;guide&quot;:&quot;none&quot;
// },{
// &quot;aesthetic&quot;:&quot;size&quot;,
// &quot;values&quot;:[0.6,0.6],
// &quot;limits&quot;:[true,false],
// &quot;guide&quot;:&quot;none&quot;
// },{
// &quot;aesthetic&quot;:&quot;alpha&quot;,
// &quot;values&quot;:[1.0,1.0],
// &quot;limits&quot;:[true,false],
// &quot;guide&quot;:&quot;none&quot;
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;x&quot;,
// &quot;ymin&quot;:&quot;min&quot;,
// &quot;lower&quot;:&quot;lower&quot;,
// &quot;middle&quot;:&quot;middle&quot;,
// &quot;upper&quot;:&quot;upper&quot;,
// &quot;ymax&quot;:&quot;max&quot;,
// &quot;fill&quot;:&quot;isIncreased&quot;,
// &quot;color&quot;:&quot;isIncreased&quot;,
// &quot;linetype&quot;:&quot;isIncreased&quot;,
// &quot;size&quot;:&quot;isIncreased&quot;,
// &quot;alpha&quot;:&quot;isIncreased&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;data&quot;:{
// &quot;middle&quot;:[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],
// &quot;min&quot;:[64.08,64.43,64.55,64.38,63.92,63.76,62.99,62.59,61.86,61.74,62.55,63.0,63.2,63.36,63.92,63.66,63.7,65.37,65.11,65.01],
// &quot;max&quot;:[63.77,64.25,64.06,63.84,63.65,62.95,62.02,61.63,61.56,61.39,62.43,62.49,63.12,63.2509,63.74,63.6,63.18,64.64,64.6507,64.89],
// &quot;isIncreased&quot;:[false,false,false,false,false,false,false,false,false,false,false,false,false,false,false,false,false,false,false,false],
// &quot;upper&quot;:[64.25,65.1,64.64,64.71,64.48,63.81,63.01,62.62,62.14,62.63,63.11,63.26,63.75,64.12,64.24,64.39,64.86,65.4698,65.42,65.66],
// &quot;lower&quot;:[64.02,64.96,64.31,64.32,64.24,63.15,62.7,61.9,61.85,62.49,63.11,63.05,63.68,63.99,63.91,64.29,64.42,64.64,65.08,65.47],
// &quot;x&quot;:[1.7328384E12,1.7326656E12,1.7325792E12,1.7324928E12,1.7322336E12,1.7321472E12,1.7320608E12,1.7319744E12,1.731888E12,1.7316288E12,1.7315424E12,1.731456E12,1.7313696E12,1.7312832E12,1.731024E12,1.7309376E12,1.7308512E12,1.7307648E12,1.7306784E12,1.7304192E12],
// &quot;close&quot;:[64.02,64.96,64.31,64.32,64.24,63.15,62.7,61.9,61.85,62.49,63.11,63.05,63.68,63.99,63.91,64.29,64.42,64.64,65.08,65.47],
// &quot;open&quot;:[64.25,65.1,64.64,64.71,64.48,63.81,63.01,62.62,62.14,62.63,63.11,63.26,63.75,64.12,64.24,64.39,64.86,65.4698,65.42,65.66]
// },
// &quot;whisker_width&quot;:0.0,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;inherit_aes&quot;:false,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;boxplot&quot;,
// &quot;data_meta&quot;:{
// &quot;series_annotations&quot;:[{
// &quot;type&quot;:&quot;datetime&quot;,
// &quot;column&quot;:&quot;x&quot;
// },{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;min&quot;
// },{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;lower&quot;
// },{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;upper&quot;
// },{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;max&quot;
// },{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;open&quot;
// },{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;close&quot;
// },{
// &quot;type&quot;:&quot;bool&quot;,
// &quot;column&quot;:&quot;isIncreased&quot;
// }]
// },
// &quot;tooltips&quot;:{
// &quot;formats&quot;:[{
// &quot;field&quot;:&quot;x&quot;,
// &quot;format&quot;:&quot;%d/%m/%y&quot;
// },{
// &quot;field&quot;:&quot;open&quot;,
// &quot;format&quot;:&quot;.2f&quot;
// },{
// &quot;field&quot;:&quot;max&quot;,
// &quot;format&quot;:&quot;.2f&quot;
// },{
// &quot;field&quot;:&quot;min&quot;,
// &quot;format&quot;:&quot;.2f&quot;
// },{
// &quot;field&quot;:&quot;close&quot;,
// &quot;format&quot;:&quot;.2f&quot;
// }],
// &quot;title&quot;:&quot;@x&quot;,
// &quot;lines&quot;:[&quot;open|@open&quot;,&quot;high|@max&quot;,&quot;low|@min&quot;,&quot;close|@close&quot;],
// &quot;disable_splitting&quot;:true
// }
// }],
// &quot;spec_id&quot;:&quot;11&quot;
// };
//        var containerDiv = document.getElementById(&quot;W06cHK&quot;);
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//        var options = {
//            sizing: {
//                width_mode: &quot;fixed&quot;,
//                height_mode: &quot;fixed&quot;,
//                width: 600.0,
//                height: 400.0
//            }
//        };
//        var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//        if (toolbar) {
//          toolbar.bind(fig);
//        }
//
//    // ----------
//    })();
//
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=68f8812c-988c-4207-9a61-2cd1c177a042 width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pDLmNgk .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pDLmNgk .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pDLmNgk .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pDLmNgk .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pDLmNgk .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pDLmNgk .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pDLmNgk .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pDLmNgk .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dEe9hyt .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pDLmNgk .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pDLmNgk .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-st

// %%
dfRaw.head(100).plot {
    ribbon {
        x(timestamp)
        y {
            axis.name = "Cost"
            scale = continuous(60.0..75.0)
        }
        yMin(low)
        yMax(high)
        fillColor = Color.hex(0x3f21e6)
        alpha = 0.65
        borderLine {
            color = Color.RED
            width = 0.8
            type = LineType.DASHED
        }
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;NHw0hD&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//        var plotSpec={
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;high&quot;:[63.77,64.25,64.06,63.84,63.65,62.95,62.02,61.63,61.56,61.39,62.43,62.49,63.12,63.2509,63.74,63.6,63.18,64.64,64.6507,64.89,65.255,65.32,65.52,66.6,66.79,66.952,66.58,68.68,69.305,69.605,69.58,69.97,70.16,69.47,68.995,68.985,69.07,68.86,68.87,69.72,70.2,70.41,71.63,71.69,71.46,70.84,71.305,70.6,71.18,70.38,70.6,71.
quot;,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;alpha&quot;:0.65,
// &quot;inherit_aes&quot;:false,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;ribbon&quot;,
// &quot;fill&quot;:&quot;#3f21e6&quot;,
// &quot;data&quot;:{
// }
// }],
// &quot;data_meta&quot;:{
// &quot;series_annotations&quot;:[{
// &quot;type&quot;:&quot;datetime&quot;,
// &quot;column&quot;:&quot;timestamp&quot;
// },{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;low&quot;
// },{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;high&quot;
// }]
// },
// &quot;spec_id&quot;:&quot;23&quot;
// };
//        var containerDiv = document.getElementById(&quot;NHw0hD&quot;);
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//        var options = {
//            sizing: {
//                width_mode: &quot;fixed&quot;,
//                height_mode: &quot;fixed&quot;,
//                width: 600.0,
//                height: 400.0
//            }
//        };
//        var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//        if (toolbar) {
//          toolbar.bind(fig);
//        }
//
//    // ----------
//    })();
//
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=45461d8f-3ddd-4400-8eb9-29dbaaca1fe7 width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pz1EVG5 .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pz1EVG5 .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pz1EVG5 .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pz1EVG5 .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pz1EVG5 .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pz1EVG5 .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pz1EVG5 .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pz1EVG5 .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dcNCKTQ .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pz1EVG5 .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pz1EVG5 .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dcNCKTQ .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pz1EVG5 .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pz1EVG5 .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dcNCKTQ .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dcNCKTQ .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dcNCKTQ .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: norma

// %%
val dataframeDividends = DataFrame.readCSV("data/dividends_KO.csv")
dataframeDividends.head()
// Out:
//             <iframe onload="o_resize_iframe_out_11()" style="width:100%;" class="result_container" id="iframe_out_11" frameBorder="0" srcdoc="        &lt;html theme='dark'&gt;
//         &lt;head&gt;
//             &lt;style type=&quot;text&sol;css&quot;&gt;
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
//     white-space: nowrap;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody &gt; tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody &gt; tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody &gt; tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover &gt; td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// &sol;* formatting *&sol;
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
// :root {
//     --scroll-bg: #f5f5f5;
//     --scroll-fg: #b3b3b3;
// }
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;]{
//     --scroll-bg: #3c3c3c;
//     --scroll-fg: #97e1fb;
// }
// body {
//     scrollbar-color: var(--scroll-fg) var(--scroll-bg);
// }
// body::-webkit-scrollbar {
//     width: 10px; &sol;* Mostly for vertical scrollbars *&sol;
//     height: 10px; &sol;* Mostly for horizontal scrollbars *&sol;
// }
// body::-webkit-scrollbar-thumb {
//     background-color: var(--scroll-fg);
// }
// body::-webkit-scrollbar-track {
//     background-color: var(--scroll-bg);
// }
//             &lt;&sol;style&gt;
//         &lt;&sol;head&gt;
//         &lt;body&gt;
//             &lt;table class=&quot;dataframe&quot; id=&quot;df_671088660&quot;&gt;&lt;&sol;table&gt;
//
// &lt;p class=&quot;dataframe_description&quot;&gt;DataFrame: rowsCount = 5, columnsCount = 2&lt;&sol;p&gt;
//
//         &lt;&sol;body&gt;
//         &lt;script&gt;
//             (function () {
//     window.DataFrame = window.DataFrame || new (function () {
//         this.addTable = function (df) {
//             let cols = df.cols;
//             for (let i = 0; i &lt; cols.length; i++) {
//                 for (let c of cols[i].children) {
//                     cols[c].parent = i;
//                 }
//             }
//             df.nrow = 0
//             for (let i = 0; i &lt; df.cols.length; i++) {
//                 if (df.cols[i].values.length &gt; df.nrow) df.nrow = df.cols[i].values.length
//             }
//             if (df.id === df.rootId) {
//                 df.expandedFrames = new Set()
//                 df.childFrames = {}
//                 const table = this.getTableElement(df.id)
//                 table.df = df
//                 for (let i = 0; i &lt; df.cols.length; i++) {
//                     let col = df.cols[i]
//                     if (col.parent === undefined &amp;&amp; col.children.length &gt; 0) col.expanded = true
//                 }
//             } else {
//                 const rootDf = this.getTableData(df.rootId)
//                 rootDf.childFrames[df.id] = df
//             }
//         }
//
//         this.computeRenderData = function (df) {
//             let result = []
//             let pos = 0
//             for (let col = 0; col &lt; df.cols.length; col++) {
//                 if (df.cols[col].parent === undefined)
//                     pos += this.computeRenderDataRec(df.cols, col, pos, 0, result, false, false)
//             }
//             for (let i = 0; i &lt; result.length; i++) {
//                 let row = result[i]
//                 for (let j = 0; j &lt; row.length; j++) {
//                     let cell = row[j]
//                     if (j === 0)
//                         cell.leftBd = false
//                     if (j &lt; row.length - 1) {
//                         let nextData = row[j + 1]
//                         if (nextData.leftBd) cell.rightBd = true
//                         else if (cell.rightBd) nextData.leftBd = true
//                     } else cell.rightBd = false
//                 }
//             }
//             return result
//         }
//
//         this.computeRenderDataRec = function (cols, colId, pos, depth, result, leftBorder, rightBorder) {
//             if (result.length === depth) {
//                 const array = [];
//                 if (pos &gt; 0) {
//                     let j = 0
//                     for (let i = 0; j &lt; pos; i++) {
//                         let c = result[depth - 1][i]
//                         j += c.span
//                         let copy = Object.assign({empty: true}, c)
//                         array.push(copy)
//                     }
//                 }
//                 result.push(array)
//             }
//             const col = cols[colId];
//             let size = 0;
//             if (col.expanded) {
//                 let childPos = pos
//                 for (let i = 0; i &lt; col.children.length; i++) {
//                     let child = col.children[i]
//                     let childLeft = i === 0 &amp;&amp; (col.children.length &gt; 1 || leftBorder)
//                     let childRight = i === col.children.length - 1 &amp;&amp; (col.children.length &gt; 1 || rightBorder)
//                     let childSize = this.computeRenderDataRec(cols, child, childPos, depth + 1, result, childLeft, childRight)
//                     childPos += childSize
//                     size += childSize
//                 }
//             } else {
//                 for (let i = depth + 1; i &lt; result.length; i++)
//                     result[i].push({id: colId, span: 1, leftBd: leftBorder, rightBd: rightBorder, empty: true})
//                 size = 1
//             }
//             let left = leftBorder
//             let right = rightBorder
//             if (size

// %%
// Step 1: Group dividends by year
val dividendsByYear = dataframeDividends
    .groupBy { it["Date"] }
    .aggregate { mean("Dividend (USD)") into "annualDividend" }
    .rename("Date" to "year")

// Step 2: Calculate average price per year
val rawByYear = dfRaw
    .add("year") { row -> (row["timestamp"] as kotlinx.datetime.LocalDate).year }
    .groupBy("year")
    .aggregate { mean("close") into "averagePrice" }

// Step 3: Calculate dividend yield per year
val annualYield = dividendsByYear.innerJoin(rawByYear, "year")
    .add("yield") { row ->
        val dividend = row["annualDividend"] as Double
        val price = row["averagePrice"] as Double
        dividend / price
    }

// Step 4: Calculate yield percentiles based on historical data
val yields = annualYield["yield"].cast<Double>().values().toList()

val minYield = yields.min()
val maxYield = yields.max()
val avgYield = yields.average()

fun List<Double>.percentile(p: Double): Double {
    if (this.isEmpty()) return Double.NaN
    val sorted = this.sorted()
    val index = p / 100.0 * (sorted.size - 1)
    return if (index % 1 == 0.0) {
        sorted[index.toInt()]
    } else {
        val lower = sorted[Math.floor(index).toInt()]
        val upper = sorted[Math.ceil(index).toInt()]
        lower + (upper - lower) * (index - Math.floor(index))
    }
}

val targetYieldForLowerBandPrice = yields.percentile(95.0)
val targetYieldForUpperBandPrice = yields.percentile(5.0)
val targetYieldForFairBandPrice = yields.percentile(50.0)

// Step 5: Calculate Geraldine Weiss bands
val bands = annualYield.select("year", "annualDividend").add {
    // "lower" price band corresponds to the HIGHEST historical yield (buy signal)
    "lower" from { (it["annualDividend"] as Double) / targetYieldForLowerBandPrice }
    // "fair" price band corresponds to the median/average historical yield
    "fair" from { (it["annualDividend"] as Double) / targetYieldForFairBandPrice }
    // "upper" price band corresponds to the LOWEST historical yield (sell signal)
    "upper" from { (it["annualDividend"] as Double) / targetYieldForUpperBandPrice }
}

val realPrices = rawByYear.select("year", "averagePrice")

val finalData = bands.join(realPrices) { it["year"] }

finalData.plot {
    step {
        x("year")
        y("lower")
        color = Color.GREEN
    }
    step {
        x("year")
        y("fair")
        color = Color.BLUE
    }
    step {
        x("year")
        y("upper")
        color = Color.RED
    }
    line {
        x("year")
        y("averagePrice")
        color = Color.BLACK
    }
    layout {
        title = "Geraldine Weiss Bands + Annual Average Price (Step Plot)"
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;6VSTba&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//        var plotSpec={
// &quot;ggtitle&quot;:{
// &quot;text&quot;:&quot;Geraldine Weiss Bands + Annual Average Price (Step Plot)&quot;
// },
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;year&quot;:[2024.0,2023.0,2022.0,2021.0,2020.0,2019.0,2018.0,2017.0,2016.0,2015.0,2014.0,2013.0],
// &quot;lower&quot;:[57.35481818809755,54.398384260876036,52.033237119098814,49.66808997732159,48.48551640643298,47.30294283554438,46.120369264655764,43.75522212287854,41.39007498110132,39.02492783932411,36.06849391210258,33.112059984881064],
// &quot;upper&quot;:[68.30654249218453,64.78558669361833,61.96882205476535,59.152057415912374,57.74367509648589,56.33529277705941,54.92691045763292,52.110145818779955,49.29338117992698,46.476616541074016,42.955660742507796,39.43470494394159],
// &quot;fair&quot;:[62.04096946768156,58.842981350790765,56.28459085727812,53.72620036376548,52.447005117009155,51.16780987025284,49.888614623496515,47.330224129983876,44.77183363647123,42.213443142958596,39.01545502606779,35.81746690917699],
// &quot;averagePrice&quot;:[64.06023809523805,59.91321999999998,61.673991633466116,54.094464285714274,49.9993280632411,50.82182539682541,45.413545816733055,44.31960159362553,43.527813492063494,41.23492063492066,40.79527341269842,39.66646785714287]
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;limits&quot;:[null,null]
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;year&quot;,
// &quot;y&quot;:&quot;lower&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;color&quot;:&quot;#3ba272&quot;,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;inherit_aes&quot;:false,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;step&quot;,
// &quot;data&quot;:{
// }
// },{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;year&quot;,
// &quot;y&quot;:&quot;fair&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;color&quot;:&quot;#5470c6&quot;,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;inherit_aes&quot;:false,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;step&quot;,
// &quot;data&quot;:{
// }
// },{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;year&quot;,
// &quot;y&quot;:&quot;upper&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;color&quot;:&quot;#ee6666&quot;,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;inherit_aes&quot;:false,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;step&quot;,
// &quot;data&quot;:{
// }
// },{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;year&quot;,
// &quot;y&quot;:&quot;averagePrice&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;color&quot;:&quot;#000000&quot;,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;inherit_aes&quot;:false,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;line&quot;,
// &quot;data&quot;:{
// }
// }],
// &quot;data_meta&quot;:{
// &quot;series_annotations&quot;:[{
// &quot;type&quot;:&quot;int&quot;,
// &quot;column&quot;:&quot;year&quot;
// },{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;lower&quot;
// },{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;fair&quot;
// },{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;upper&quot;
// },{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;averagePrice&quot;
// }]
// },
// &quot;spec_id&quot;:&quot;59&quot;
// };
//        var containerDiv = document.getElementById(&quot;6VSTba&quot;);
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//        var options = {
//            sizing: {
//                width_mode: &quot;fixed&quot;,
//                height_mode: &quot;fixed&quot;,
//                width: 600.0,
//                height: 400.0
//            }
//        };
//        var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//        if (toolbar) {
//          toolbar.bind(fig);
//        }
//
//    // ----------
//    })();
//
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=1b149119-26f5-4db0-b159-0bca3e5dec17 width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pGj4Rbn .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pGj4Rbn .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pGj4Rbn .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pGj4Rbn .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pGj4Rbn .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pGj4Rbn .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pGj4Rbn .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pGj4Rbn .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dJI9vFN .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pGj4Rbn .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pGj4Rbn .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dJI9vFN .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pGj4Rbn .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pGj4Rbn .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dJI9vFN .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dJI9vFN .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dJI9vFN .tooltip-label {
// fill: #474747;
// font-weight: bold;

// %%
val df = DataFrame.readCSV("data/portfolio_distribution.csv")

df.plot {
    pie {
        slice("percentage")
        fillColor("company") {
            scale = categorical()
        }
        size = 33.0
        hole = 0.3
        alpha = 0.8
    }
    layout.style(
        Style.Void
    )
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;UPbg8v&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//        var plotSpec={
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;percentage&quot;:[3.06,1.55,2.13,0.6,2.28,1.52,1.2,2.65,0.47,1.32,0.76,1.43,1.44,0.79,0.83,1.57,0.65,1.18,1.89,1.5,0.63,0.32,0.93,1.43,1.33,0.96,2.27,1.16,0.78,0.94,1.45,1.19,0.43,0.82,1.91,1.92,0.76,1.37,1.33,1.95,1.49,1.57,0.56,1.79,1.87,1.67,1.72,0.66,1.29,3.31,1.81,1.55,0.92,1.39,1.66,0.67,1.64,1.55,1.16,1.95,1.41,1.42,0.83,1.74,1.21,1.71,0.84,1.59,1.12,0.6,0.51,0.58,0.6,1.09,0.84,0.95],
// &quot;company&quot;:[&quot;Allianz&quot;,&quot;Apple&quot;,&quot;AXA&quot;,&quot;Dow Inc&quot;,&quot;Mondelez&quot;,&quot;Kimberly Clark&quot;,&quot;E.ON&quot;,&quot;München RE&quot;,&quot;RWE&quot;,&quot;Siemens&quot;,&quot;American Electric Power&quot;,&quot;Microsoft&quot;,&quot;Deutsche Post&quot;,&quot;Iberdrola&quot;,&quot;Kraft Heinz&quot;,&quot;General Mills&quot;,&quot;Archer Daniels Midland&quot;,&quot;AT&amp;T&quot;,&quot;IBM&quot;,&quot;Watsco&quot;,&quot;American Tower&quot;,&quot;Endesa&quot;,&quot;Enbridge&quot;,&quot;CIBC&quot;,&quot;National Grid&quot;,&quot;ExxonMobil&quot;,&quot;Coca Cola&quot;,&quot;Chevron&quot;,&quot;Aegon&quot;,&quot;CVS Health&quot;,&quot;Diageo&quot;,&quot;3M&quot;,&quot;REE&quot;,&quot;Royal Dutch Shell&quot;,&quot;Johnson and Johnson&quot;,&quot;Blackrock&quot;,&quot;Illinois Tool Works&quot;,&quot;Kenvue&quot;,&quot;Verizon&quot;,&quot;Cisco&quot;,&quot;Abbvie&quot;,&quot;Altria&quot;,&quot;Emerson&quot;,&quot;JP Morgan Chase&quot;,&quot;Texas Instruments&quot;,&quot;Unilever&quot;,&quot;Deutsche Telekom&quot;,&quot;Naturgy&quot;,&quot;Realty Income&quot;,&quot;Philip Morris&quot;,&quot;Pepsi&quot;,&quot;Procter and Gamble&quot;,&quot;Pfizer&quot;,&quot;Merck&quot;,&quot;Home Depot&quot;,&quot;Stanley Black &amp; Decker&quot;,&quot;BATS&quot;,&quot;Lockheed Martin&quot;,&quot;BMY&quot;,&quot;Hershey&quot;,&quot;Clorox&quot;,&quot;TROW&quot;,&quot;General Dynamics&quot;,&quot;McDonalds&quot;,&quot;Target&quot;,&quot;Starbucks&quot;,&quot;Rio Tinto&quot;,&quot;Blackstone&quot;,&quot;Lowe&quot;,&quot;Medtronic&quot;,&quot;BXMT&quot;,&quot;Tyson Foods&quot;,&quot;Hormel Foods&quot;,&quot;Alphabet&quot;,&quot;Blackrock Science Technology&quot;,&quot;Reaves Utility Income&quot;]
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;fill&quot;,
// &quot;discrete&quot;:true
// }],
// &quot;layers&quot;:[{
// &quot;hole&quot;:0.3,
// &quot;mapping&quot;:{
// &quot;slice&quot;:&quot;percentage&quot;,
// &quot;fill&quot;:&quot;company&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;size&quot;:33.0,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;alpha&quot;:0.8,
// &quot;inherit_aes&quot;:false,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;pie&quot;,
// &quot;data&quot;:{
// }
// }],
// &quot;theme&quot;:{
// &quot;name&quot;:&quot;classic&quot;,
// &quot;axis&quot;:{
// &quot;blank&quot;:true
// },
// &quot;line&quot;:{
// &quot;blank&quot;:true
// },
// &quot;axis_ontop&quot;:false,
// &quot;axis_ontop_y&quot;:false,
// &quot;axis_ontop_x&quot;:false
// },
// &quot;data_meta&quot;:{
// &quot;series_annotations&quot;:[{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;percentage&quot;
// },{
// &quot;type&quot;:&quot;str&quot;,
// &quot;column&quot;:&quot;company&quot;
// }]
// },
// &quot;spec_id&quot;:&quot;38&quot;
// };
//        var containerDiv = document.getElementById(&quot;UPbg8v&quot;);
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//        var options = {
//            sizing: {
//                width_mode: &quot;fixed&quot;,
//                height_mode: &quot;fixed&quot;,
//                width: 600.0,
//                height: 400.0
//            }
//        };
//        var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//        if (toolbar) {
//          toolbar.bind(fig);
//        }
//
//    // ----------
//    })();
//
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=7a2d6498-7ff3-4580-8e54-bd0a0accfd6c width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pEsfpaI .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pEsfpaI .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pEsfpaI .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pEsfpaI .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pEsfpaI .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pEsfpaI .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pEsfpaI .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pEsfpaI .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dAIVkSG .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pEsfpaI .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pEsfpaI .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dAIVkSG .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pEsfpaI .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pEsfpaI .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dAIVkSG .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dAIVkSG .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dAIVkSG .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pEsfpaI">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
//     </path>
//     <g transform="translate(6.5 6.5 ) ">
//       <g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//         <g transform="translate(0.0 387.0 ) ">
//         </g>
//         <g tran

// %%
val df = DataFrame.readCSV("data/sector_representation.csv")

df.plot {
    pie {
        slice("share")
        fillColor("sector") {
            scale = categorical(
                "Cyclical" to Color.hex("#F44336"),    // Red
                "Sensitive" to Color.hex("#FFC107"),   // Amber
                "Defensive" to Color.hex("#4CAF50")    // Green
            )
        }
        explode("explode")
        size = 25.0
    }
    layout {
        style(Style.Void)
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;wINXnG&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//        var plotSpec={
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;explode&quot;:[0.2,0.08,0.16],
// &quot;share&quot;:[32.92,23.75,43.33],
// &quot;sector&quot;:[&quot;Cyclical&quot;,&quot;Sensitive&quot;,&quot;Defensive&quot;]
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;fill&quot;,
// &quot;values&quot;:[&quot;#F44336&quot;,&quot;#FFC107&quot;,&quot;#4CAF50&quot;],
// &quot;limits&quot;:[&quot;Cyclical&quot;,&quot;Sensitive&quot;,&quot;Defensive&quot;]
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;slice&quot;:&quot;share&quot;,
// &quot;fill&quot;:&quot;sector&quot;,
// &quot;explode&quot;:&quot;explode&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;size&quot;:25.0,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;inherit_aes&quot;:false,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;pie&quot;,
// &quot;data&quot;:{
// }
// }],
// &quot;theme&quot;:{
// &quot;name&quot;:&quot;classic&quot;,
// &quot;axis&quot;:{
// &quot;blank&quot;:true
// },
// &quot;line&quot;:{
// &quot;blank&quot;:true
// },
// &quot;axis_ontop&quot;:false,
// &quot;axis_ontop_y&quot;:false,
// &quot;axis_ontop_x&quot;:false
// },
// &quot;data_meta&quot;:{
// &quot;series_annotations&quot;:[{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;share&quot;
// },{
// &quot;type&quot;:&quot;str&quot;,
// &quot;column&quot;:&quot;sector&quot;
// },{
// &quot;type&quot;:&quot;float&quot;,
// &quot;column&quot;:&quot;explode&quot;
// }]
// },
// &quot;spec_id&quot;:&quot;32&quot;
// };
//        var containerDiv = document.getElementById(&quot;wINXnG&quot;);
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//        var options = {
//            sizing: {
//                width_mode: &quot;fixed&quot;,
//                height_mode: &quot;fixed&quot;,
//                width: 600.0,
//                height: 400.0
//            }
//        };
//        var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//        if (toolbar) {
//          toolbar.bind(fig);
//        }
//
//    // ----------
//    })();
//
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=482d8e25-7087-4a6a-a2b8-4b571bf80904 width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pPPrjni .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pPPrjni .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pPPrjni .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pPPrjni .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pPPrjni .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pPPrjni .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pPPrjni .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pPPrjni .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #doOHaBA .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pPPrjni .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pPPrjni .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #doOHaBA .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pPPrjni .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pPPrjni .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #doOHaBA .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #doOHaBA .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #doOHaBA .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pPPrjni">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
//     </path>
//     <g transform="translate(6.5 6.5 ) ">
//       <g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//         <g transform="translate(0.0 387.0 ) ">
//         </g>
//         <g transform="">
//         </g>
//       </g>
//       <g clip-path="url(#cp1sVKO)" clip-bounds-jfx="[rect (0.0, 0.0), (467.63299898805946, 387.0)]">
//         <g transform="">
//           <g>
//             <g>
//               <g>
//                 <path d="M212.33000076213222 180.71992283888054 L102.49035607575411 240.38777394121377 A125.0 125.0 0.0 0 1 212.33000076213222 55.719922838880535 L212.33000076213222 180.71992283888054 A0.0 0.0 0.0 0 0 212.33000076213222 180.71992283888054 " fill="rgb(244,67,54)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M240.60450694935915 186.15677490564315 L240.60450694935915 61.15677490564315 A125.0 125.0 0.0 0 1 365.21917366600013 176.34938793966253 L240.60450694935915 186.15677490564315 A0.0 0.0 0.0 0 0 240.60450694935915 186.15677490564315 " fill="rgb(255,193,7)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M239.49881450431553 212.67579975187164 L364.11348122095654 202.86841278589102 A125.0 125.0 0.0 0 1 129.65916981793742 272.3436508542049 L239.49881450431553 212.67579975187164 A0.0 0.0 0.0 0 0 239.49881450431553 212.67579975187164 " fill="rgb(76,175,80)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M102.49035607575411 240.38777394121377 A125.0 125.0 0.0 0 1 212.33000076213222 55.719922838880535 M212.33000076213222 180.71992283888054 A0.0 0.0 0.0 0 0 212.33000076213222 180.71992283888054 " fill="none" stroke-width="0.75" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M240.60450694935915 61.15677490564315 A125.0 125.0

// %%
val df = DataFrame.readCSV("data/grouped_dividends_by_month.csv")

val dataset = df.gather(
    "2012", "2013", "2014", "2015", "2016", "2017", "2018",
    "2019", "2020", "2021", "2022", "2023", "2024", "2025"
).into("year", "dividend")

dataset.groupBy("year").plot {
    //layout.size = 1200 to 600
    layout.title = "Monthly Dividends by Year"
    bars {
        x("month")
        y("dividend")
        fillColor("year") {
            scale = categorical(
                "2012" to Color.hex("#1f77b4"),
                "2013" to Color.hex("#ff7f0e"),
                "2014" to Color.hex("#2ca02c"),
                "2015" to Color.hex("#d62728"),
                "2016" to Color.hex("#9467bd"),
                "2017" to Color.hex("#8c564b"),
                "2018" to Color.hex("#e377c2"),
                "2019" to Color.hex("#7f7f7f"),
                "2020" to Color.hex("#bcbd22"),
                "2021" to Color.hex("#17becf"),
                "2022" to Color.hex("#aec7e8"),
                "2023" to Color.hex("#6F4E37"),
                "2024" to Color.hex("#C2D4AB"),
                "2025" to Color.hex("#B5651D")
            )
        }
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;w8trdD&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//        var plotSpec={
// &quot;ggtitle&quot;:{
// &quot;text&quot;:&quot;Monthly Dividends by Year&quot;
// },
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;&amp;merged_groups&quot;:[&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2017&quot;,&quot;2017&quot;,&quot;2017&quot;,&quot;2017&quot;,&quot;2017&quot;,&quot;2017&quot;,&quot;2017&quot;,&quot;2017&quot;,&quot;2017&quot;,&quot;2017&quot;,&quot;2017&quot;,&quot;2017&quot;,&quot;2018&quot;,&quot;2018&quot;,&quot;2018&quot;,&quot;2018&quot;,&quot;2018&quot;,&quot;2018&quot;,&quot;2018&quot;,&quot;2018&quot;,&quot;2018&quot;,&quot;2018&quot;,&quot;2018&quot;,&quot;2018&quot;,&quot;2019&quot;,&quot;2019&quot;,&quot;2019&quot;,&quot;2019&quot;,&quot;2019&quot;,&quot;2019&quot;,&quot;2019&quot;,&quot;2019&quot;,&quot;2019&quot;,&quot;2019&quot;,&quot;2019&quot;,&quot;2019&quot;,&quot;2020&quot;,&quot;2020&quot;,&quot;2020&quot;,&quot;2020&quot;,&quot;2020&quot;,&quot;2020&quot;,&quot;2020&quot;,&quot;2020&quot;,&quot;2020&quot;,&quot;2020&quot;,&quot;2020&quot;,&quot;2020&quot;,&quot;2021&quot;,&quot;2021&quot;,&quot;2021&quot;,&quot;2021&quot;,&quot;2021&quot;,&quot;2021&quot;,&quot;2021&quot;,&quot;2021&quot;,&quot;2021&quot;,&quot;2021&quot;,&quot;2021&quot;,&quot;2021&quot;,&quot;2022&quot;,&quot;2022&quot;,&quot;2022&quot;,&quot;2022&quot;,&quot;2022&quot;,&quot;2022&quot;,&quot;2022&quot;,&quot;2022&quot;,&quot;2022&quot;,&quot;2022&quot;,&quot;2022&quot;,&quot;2022&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2024&quot;,&quot;2024&quot;,&quot;2024&quot;,&quot;2024&quot;,&quot;2024&quot;,&quot;2024&quot;,&quot;2024&quot;,&quot;2024&quot;,&quot;2024&quot;,&quot;2024&quot;,&quot;2024&quot;,&quot;2024&quot;,&quot;2025&quot;,&quot;2025&quot;,&quot;2025&quot;,&quot;2025&quot;,&quot;2025&quot;,&quot;2025&quot;,&quot;2025&quot;,&quot;2025&quot;,&quot;2025&quot;,&quot;2025&quot;,&quot;2025&quot;,&quot;2025&quot;],
// &quot;month&quot;:[&quot;January&quot;,&quot;February&quot;,&quot;March&quot;,&quot;April&quot;,&quot;May&quot;,&quot;June&quot;,&quot;July&quot;,&quot;August&quot;,&quot;September&quot;,&quot;October&quot;,&quot;November&quot;,&quot;December&quot;,&quot;January&quot;,&quot;February&quot;,&quot;March&quot;,&quot;April&quot;,&quot;May&quot;,&quot;June&quot;,&quot;July&quot;,&quot;August&quot;,&quot;September&quot;,&quot;October&quot;,&quot;November&quot;,&quot;December&quot;,&quot;January&quot;,&quot;February&quot;,&quot;March&quot;,&quot;April&quot;,&quot;May&quot;,&quot;June&quot;,&quot;July&quot;,&quot;August&quot;,&quot;September&quot;,&quot;October&quot;,&quot;November&quot;,&quot;December&quot;,&quot;January&quot;,&quot;February&quot;,&quot;March&quot;,&quot;April&quot;,&quot;May&quot;,&quot;June&quot;,&quot;July&quot;,&quot;August&quot;,&quot;September&quot;,&quot;October&quot;,&quot;November&quot;,&quot;December&quot;,&quot;January&quot;,&quot;February&quot;,&quot;March&quot;,&quot;April&quot;,&quot;May&quot;,&quot;June&quot;,&quot;July&quot;,&quot;August&quot;,&quot;September&quot;,&quot;October&quot;,&quot;November&quot;,&quot;December&quot;,&quot;January&quot;,&quot;February&quot;,&quot;March&quot;,&quot;April&quot;,&quot;May&quot;,&quot;June&quot;,&quot;July&quot;,&quot;August&quot;,&quot;September&quot;,&quot;October&quot;,&quot;November&quot;,&quot;December&quot;,&quot;January&quot;,&quot;February&quot;,&quot;March&quot;,&quot;April&quot;,&quot;May&quot;,&quot;June&quot;,&quot;July&quot;,&quot;August&quot;,&quot;September&quot;,&quot;October&quot;,&quot;November&quot;,&quot;December&quot;,&quot;January&quot;,&quot;February&quot;,&quot;March&quot;,&quot;April&quot;,&quot;May&quot;,&quot;June&quot;,&quot;July&quot;,&quot;August&quot;,&quot;September&quot;,&quot;October&quot;,&quot;November&quot;,&quot;December&quot;,&quot;January&quot;,&quot;February&quot;,&quot;March&quot;,&quot;April&quot;,&quot;May&quot;,&quot;June&quot;,&quot;July&quot;,&quot;August&quot;,&quot;September&quot;,&quot;October&quot;,&quot;November&quot;,&quot;December&quot;,&quot;January&quot;,&quot;February&quot;,&quot;March&quot;,&quot;April&quot;,&quot;May&quot;,&quot;June&quot;,&quot;July&quot;,&quot;August&quot;,&quot;September&quot;,&quot;October&quot;,&quot;November&quot;,&quot;December&quot;,&quot;January&quot;,&quot;February&quot;,&quot;March&quot;,&quot;April&quot;,&quot;May&quot;,&quot;June&quot;,&quot;July&quot;,&quot;August&quot;,&quot;September&quot;,&quot;October&quot;,&quot;November&quot;,&quot;December&quot;,&quot;January&quot;,&quot;February&quot;,&quot;March&quot;,&quot;April&quot;,&quot;May&quot;,&quot;June&quot;,&quot;July&quot;,&quot;August&quot;,&quot;September&quot;,&quot;October&quot;,&quot;November&quot;,&quot;December&quot;,&quot;January&quot;,&quot;February&quot;,&quot;March&quot;,&quot;April&quot;,&quot;May&quot;,&quot;June&quot;,&quot;July&quot;,&quot;August&quot;,&quot;September&quot;,&quot;October&quot;,&quot;November&quot;,&quot;December&quot;,&quot;January&quot;,&quot;February&quot;,&quot;March&quot;,&quot;April&quot;,&quot;May&quot;,&quot;June&quot;,&quot;July&quot;,&quot;August&quot;,&quot;September&quot;,&quot;October&quot;,&quot;November&quot;,&quot;December&quot;],
// &quot;year&quot;:[&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot

// %%
import org.jetbrains.kotlinx.dataframe.api.*
import org.jetbrains.kotlinx.kandy.dsl.*
import kotlin.random.Random

fun randomColorHex(): String {
    val r = Random.nextInt(0, 256)
    val g = Random.nextInt(0, 256)
    val b = Random.nextInt(0, 256)
    return "#%02X%02X%02X".format(r, g, b)
}

val df = DataFrame.readCsv("data/grouped_dividends_by_month.csv")

val years = df.columnNames().filter { it != "month" }
val dataset = df.gather(*years.toTypedArray()).into("year", "dividend")

val colorPairs = years.map { it to Color.hex(randomColorHex()) }.toTypedArray()

dataset.groupBy("year").plot {
    layout.title = "Monthly Dividends by Year"
    bars {
        x("month")
        y("dividend")
        fillColor("year") {
            scale = categorical(*colorPairs)
            //scale = categoricalColorViridis()
        }
    }
    layout.size = 1200 to 600
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='1200' height='600' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;ZGcjXr&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//        var plotSpec={
// &quot;ggtitle&quot;:{
// &quot;text&quot;:&quot;Monthly Dividends by Year&quot;
// },
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;&amp;merged_groups&quot;:[&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2017&quot;,&quot;2017&quot;,&quot;2017&quot;,&quot;2017&quot;,&quot;2017&quot;,&quot;2017&quot;,&quot;2017&quot;,&quot;2017&quot;,&quot;2017&quot;,&quot;2017&quot;,&quot;2017&quot;,&quot;2017&quot;,&quot;2018&quot;,&quot;2018&quot;,&quot;2018&quot;,&quot;2018&quot;,&quot;2018&quot;,&quot;2018&quot;,&quot;2018&quot;,&quot;2018&quot;,&quot;2018&quot;,&quot;2018&quot;,&quot;2018&quot;,&quot;2018&quot;,&quot;2019&quot;,&quot;2019&quot;,&quot;2019&quot;,&quot;2019&quot;,&quot;2019&quot;,&quot;2019&quot;,&quot;2019&quot;,&quot;2019&quot;,&quot;2019&quot;,&quot;2019&quot;,&quot;2019&quot;,&quot;2019&quot;,&quot;2020&quot;,&quot;2020&quot;,&quot;2020&quot;,&quot;2020&quot;,&quot;2020&quot;,&quot;2020&quot;,&quot;2020&quot;,&quot;2020&quot;,&quot;2020&quot;,&quot;2020&quot;,&quot;2020&quot;,&quot;2020&quot;,&quot;2021&quot;,&quot;2021&quot;,&quot;2021&quot;,&quot;2021&quot;,&quot;2021&quot;,&quot;2021&quot;,&quot;2021&quot;,&quot;2021&quot;,&quot;2021&quot;,&quot;2021&quot;,&quot;2021&quot;,&quot;2021&quot;,&quot;2022&quot;,&quot;2022&quot;,&quot;2022&quot;,&quot;2022&quot;,&quot;2022&quot;,&quot;2022&quot;,&quot;2022&quot;,&quot;2022&quot;,&quot;2022&quot;,&quot;2022&quot;,&quot;2022&quot;,&quot;2022&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2023&quot;,&quot;2024&quot;,&quot;2024&quot;,&quot;2024&quot;,&quot;2024&quot;,&quot;2024&quot;,&quot;2024&quot;,&quot;2024&quot;,&quot;2024&quot;,&quot;2024&quot;,&quot;2024&quot;,&quot;2024&quot;,&quot;2024&quot;,&quot;2025&quot;,&quot;2025&quot;,&quot;2025&quot;,&quot;2025&quot;,&quot;2025&quot;,&quot;2025&quot;,&quot;2025&quot;,&quot;2025&quot;,&quot;2025&quot;,&quot;2025&quot;,&quot;2025&quot;,&quot;2025&quot;],
// &quot;month&quot;:[&quot;January&quot;,&quot;February&quot;,&quot;March&quot;,&quot;April&quot;,&quot;May&quot;,&quot;June&quot;,&quot;July&quot;,&quot;August&quot;,&quot;September&quot;,&quot;October&quot;,&quot;November&quot;,&quot;December&quot;,&quot;January&quot;,&quot;February&quot;,&quot;March&quot;,&quot;April&quot;,&quot;May&quot;,&quot;June&quot;,&quot;July&quot;,&quot;August&quot;,&quot;September&quot;,&quot;October&quot;,&quot;November&quot;,&quot;December&quot;,&quot;January&quot;,&quot;February&quot;,&quot;March&quot;,&quot;April&quot;,&quot;May&quot;,&quot;June&quot;,&quot;July&quot;,&quot;August&quot;,&quot;September&quot;,&quot;October&quot;,&quot;November&quot;,&quot;December&quot;,&quot;January&quot;,&quot;February&quot;,&quot;March&quot;,&quot;April&quot;,&quot;May&quot;,&quot;June&quot;,&quot;July&quot;,&quot;August&quot;,&quot;September&quot;,&quot;October&quot;,&quot;November&quot;,&quot;December&quot;,&quot;January&quot;,&quot;February&quot;,&quot;March&quot;,&quot;April&quot;,&quot;May&quot;,&quot;June&quot;,&quot;July&quot;,&quot;August&quot;,&quot;September&quot;,&quot;October&quot;,&quot;November&quot;,&quot;December&quot;,&quot;January&quot;,&quot;February&quot;,&quot;March&quot;,&quot;April&quot;,&quot;May&quot;,&quot;June&quot;,&quot;July&quot;,&quot;August&quot;,&quot;September&quot;,&quot;October&quot;,&quot;November&quot;,&quot;December&quot;,&quot;January&quot;,&quot;February&quot;,&quot;March&quot;,&quot;April&quot;,&quot;May&quot;,&quot;June&quot;,&quot;July&quot;,&quot;August&quot;,&quot;September&quot;,&quot;October&quot;,&quot;November&quot;,&quot;December&quot;,&quot;January&quot;,&quot;February&quot;,&quot;March&quot;,&quot;April&quot;,&quot;May&quot;,&quot;June&quot;,&quot;July&quot;,&quot;August&quot;,&quot;September&quot;,&quot;October&quot;,&quot;November&quot;,&quot;December&quot;,&quot;January&quot;,&quot;February&quot;,&quot;March&quot;,&quot;April&quot;,&quot;May&quot;,&quot;June&quot;,&quot;July&quot;,&quot;August&quot;,&quot;September&quot;,&quot;October&quot;,&quot;November&quot;,&quot;December&quot;,&quot;January&quot;,&quot;February&quot;,&quot;March&quot;,&quot;April&quot;,&quot;May&quot;,&quot;June&quot;,&quot;July&quot;,&quot;August&quot;,&quot;September&quot;,&quot;October&quot;,&quot;November&quot;,&quot;December&quot;,&quot;January&quot;,&quot;February&quot;,&quot;March&quot;,&quot;April&quot;,&quot;May&quot;,&quot;June&quot;,&quot;July&quot;,&quot;August&quot;,&quot;September&quot;,&quot;October&quot;,&quot;November&quot;,&quot;December&quot;,&quot;January&quot;,&quot;February&quot;,&quot;March&quot;,&quot;April&quot;,&quot;May&quot;,&quot;June&quot;,&quot;July&quot;,&quot;August&quot;,&quot;September&quot;,&quot;October&quot;,&quot;November&quot;,&quot;December&quot;,&quot;January&quot;,&quot;February&quot;,&quot;March&quot;,&quot;April&quot;,&quot;May&quot;,&quot;June&quot;,&quot;July&quot;,&quot;August&quot;,&quot;September&quot;,&quot;October&quot;,&quot;November&quot;,&quot;December&quot;,&quot;January&quot;,&quot;February&quot;,&quot;March&quot;,&quot;April&quot;,&quot;May&quot;,&quot;June&quot;,&quot;July&quot;,&quot;August&quot;,&quot;September&quot;,&quot;October&quot;,&quot;November&quot;,&quot;December&quot;],
// &quot;year&quot;:[&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2012&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2013&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2014&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2015&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quot;2016&quot;,&quo
